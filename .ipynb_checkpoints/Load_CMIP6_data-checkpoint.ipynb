# %%
import warnings
import intake
import xarray as xr
import proplot as plot
import matplotlib.pyplot as plt
import pandas as pd
import cftime

warnings.filterwarnings('ignore')

# %% [markdown]
# # Fetching data from CMIP6 archive

# %%
url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"
dataframe = intake.open_esm_datastore(url)

# %%
type(dataframe)
# Out:
# intake_esm.core.esm_datastore

# %%
dataframe.df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %%
models = dataframe.search(experiment_id="historical",
                          variable_id="pr",
                          institution_id="MOHC",
                          member_id="r1i1p1f2")

models
# Out:
# <p><strong>pangeo-cmip6 catalog with 2 dataset(s) from 2 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %pip install gcsfs
# Out:
# Collecting gcsfs
#   Downloading gcsfs-2021.11.1-py2.py3-none-any.whl (24 kB)
# Collecting google-auth-oauthlib
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: fsspec==2021.11.1 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from gcsfs) (2021.11.1)
# Requirement already satisfied: requests in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from gcsfs) (2.26.0)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-1.44.0-py2.py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: decorator>4.1.2 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from gcsfs) (5.1.0)
# Collecting google-auth>=1.2
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 1.7 MB/s eta 0:00:01
# Collecting aiohttp<4
#   Downloading aiohttp-3.8.1-cp39-cp39-macosx_10_9_x86_64.whl (574 kB)
#      |████████████████████████████████| 574 kB 1.4 MB/s eta 0:00:01
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp39-cp39-macosx_10_9_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from aiohttp<4->gcsfs) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from aiohttp<4->gcsfs) (21.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-5.2.0-cp39-cp39-macosx_10_9_x86_64.whl (45 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp39-cp39-macosx_10_9_x86_64.whl (81 kB)
#      |████████████████████████████████| 81 kB 1.8 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Requirement already satisfied: setuptools>=40.3.0 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs) (58.0.4)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs) (1.16.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: idna>=2.0 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp<4->gcsfs) (3.3)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from requests->gcsfs) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/inwaves/anaconda3/envs/surrogate/lib/python3.9/site-packages (from requests->gcsfs) (1.26.7)
# Collecting google-api-core<3.0dev,>=1.29.0
#   Downloading google_api_core-2.3.2-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 1.6 MB/s eta 0:00:01
# Collecting google-resumable-media<3.0dev,>=1.3.0
#   Downloading google_resumable_media-2.1.0-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 1.8 MB/s eta 0:00:01
# Collecting protobuf
#   Downloading protobuf-3.19.3-cp39-cp39-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 1.6 MB/s eta 0:00:01
# Collecting google-cloud-core<3.0dev,>=1.6.0
#   Downloading google_cloud_core-2.2.1-py2.py3-none-any.whl (29 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Using cached googleapis_common_protos-1.54.0-py2.py3-none-any.whl (207 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (30 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, googleapis-common-protos, google-auth, oauthlib, multidict, google-crc32c, google-api-core, frozenlist, yarl, requests-oauthlib, google-resumable-media, google-cloud-core, async-timeout, aiosignal, google-cloud-storage, google-auth-oauthlib, aiohttp, gcsfs
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 cachetools-4.2.4 frozenlist-1.2.0 gcsfs-2021.11.1 google-api-core-2.3.2 google-auth-2.3.3 google-auth-oauthlib-0.4.6 google-cloud-core-2.2.1 google-cloud-storage-1.44.0 google-crc32c-1.3.0 google-resumable-media-2.1.0 googleapis-common-protos-1.54.0 multidict-5.2.0 oauthlib-3.1.1 protobuf-3.19.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 yarl-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
datasets = models.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>

# %% [markdown]
# In this address: `activity_id.institution_id.source_id.experiment_id.table_id.grid_label`,
# - `source_id` is the model
# - `experiment_id` is the experiment
# - `table_id` is the temporal frequency
#
# Let's choose the "Amon" entry: monthly atmospheric data.

# %%
datasets.keys()
# Out:
# dict_keys(['CMIP.MOHC.UKESM1-0-LL.historical.day.gn', 'CMIP.MOHC.UKESM1-0-LL.historical.Amon.gn'])

# %%
ds = datasets["CMIP.MOHC.UKESM1-0-LL.historical.Amon.gn"]
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 144, bnds: 2, lon: 192, member_id: 1, time: 1980)
# Coordinates:
#   * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#     lat_bnds   (lat, bnds) float64 dask.array<chunksize=(144, 2), meta=np.ndarray>
#   * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#     lon_bnds   (lon, bnds) float64 dask.array<chunksize=(192, 2), meta=np.ndarray>
#   * time       (time) object 1850-01-16 00:00:00 ... 2014-12-16 00:00:00
#     time_bnds  (time, bnds) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#   * member_id  (member_id) <U8 'r1i1p1f2'
# Dimensions without coordinates: bnds
# Data variables:
#     pr         (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 600, 144, 192), meta=np.ndarray>
# Attributes: (12/51)
#     Conventions:             CF-1.7 CMIP-6.2
#     activity_id:             CMIP
#     branch_method:           standard
#     branch_time_in_child:    0.0
#     branch_time_in_parent:   144000.0
#     cmor_version:            3.4.0
#     ...                      ...
#     variant_label:           r1i1p1f2
#     status:                  2019-10-25;created;by nhn2@columbia.edu
#     netcdf_tracking_ids:     hdl:21.14100/f35b8979-27a3-4e33-9708-43fb5001fb9...
#     version_id:              v20190406
#     intake_esm_varname:      ['pr']
#     intake_esm_dataset_key:  CMIP.MOHC.UKESM1-0-LL.historical.Amon.gn

# %%
df = ds.to_dataframe()

# %% [markdown]
# # Understanding the data

# %% [markdown]
# In this data, there is one entry for each month's precipitation, for each combination of latitude and longitude.
#
# The latitude varies from -89.375 to 89.375 in 1.25 degree increments (143 values in total).
#
# The longitude varies from 0.975 to 359.0625 in 1.875 degree increments (192 values times 2 bands, 384 in total).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 109486080 entries, (-89.375, 0, 0.9375, 'r1i1p1f2', cftime.Datetime360Day(1850, 1, 16, 0, 0, 0, 0, has_year_zero=True)) to (89.375, 1, 359.0625, 'r1i1p1f2', cftime.Datetime360Day(2014, 12, 16, 0, 0, 0, 0, has_year_zero=True))
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   lat_bnds   float64
#  1   lon_bnds   float64
#  2   pr         float32
#  3   time_bnds  object
# dtypes: float32(1), float64(2), object(1)
# memory usage: 3.7+ GB

# %% [markdown]
# For each degree of latitude, we have 760,320 measurements, because there are 1980 precipitation measurements for each of the 384 values of longitude.

# %% [markdown]
# One precipitation measurement per month, for 1980 months ranging from 01/1850 to 12/2014:

# %%
df.head(13)
# Out:
#                                                    lat_bnds  lon_bnds  \
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00     -90.0       0.0
#                               1850-02-16 00:00:00     -90.0       0.0
#                               1850-03-16 00:00:00     -90.0       0.0
#                               1850-04-16 00:00:00     -90.0       0.0
#                               1850-05-16 00:00:00     -90.0       0.0
#                               1850-06-16 00:00:00     -90.0       0.0
#                               1850-07-16 00:00:00     -90.0       0.0
#                               1850-08-16 00:00:00     -90.0       0.0
#                               1850-09-16 00:00:00     -90.0       0.0
#                               1850-10-16 00:00:00     -90.0       0.0
#                               1850-11-16 00:00:00     -90.0       0.0
#                               1850-12-16 00:00:00     -90.0       0.0
#                               1851-01-16 00:00:00     -90.0       0.0
#
#                                                              pr  \
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00  2.528526e-06
#                               1850-02-16 00:00:00  1.196780e-06
#                               1850-03-16 00:00:00  3.137424e-07
#                               1850-04-16 00:00:00  1.142245e-06
#                               1850-05-16 00:00:00  1.526145e-06
#                               1850-06-16 00:00:00  2.687166e-06
#                               1850-07-16 00:00:00  3.467898e-06
#                               1850-08-16 00:00:00  2.683400e-06
#                               1850-09-16 00:00:00  1.678475e-06
#                               1850-10-16 00:00:00  7.891462e-07
#                               1850-11-16 00:00:00  1.907595e-06
#                               1850-12-16 00:00:00  2.452062e-06
#                               1851-01-16 00:00:00  1.927868e-06
#
#                                                              time_bnds
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00  1850-01-01 00:00:00
#                               1850-02-16 00:00:00  1850-02-01 00:00:00
#                               1850-03-16 00:00:00  1850-03-01 00:00:00
#                               1850-04-16 00:00:00  1850-04-01 00:00:00
#                               1850-05-16 00:00:00  1850-05-01 00:00:00
#                               1850-06-16 00:00:00  1850-06-01 00:00:00
#                               1850-07-16 00:00:00  1850-07-01 00:00:00
#                               1850-08-16 00:00:00  1850-08-01 00:00:00
#                               1850-09-16 00:00:00  1850-09-01 00:00:00
#                               1850-10-16 00:00:00  1850-10-01 00:00:00
#                               1850-11-16 00:00:00  1850-11-01 00:00:00
#                               1850-12-16 00:00:00  1850-12-01 00:00:00
#                               1851-01-16 00:00:00  1851-01-01 00:00:00

# %% [markdown]
# # Splitting the data into training-validation-test

# %%
training_set = df.loc[df.index.get_level_values("time") <= cftime.Datetime360Day(1965, 6, 16, 0, 0, 0, 0, has_year_zero=True)]
test_set = df.loc[df.index.get_level_values("time") >= cftime.Datetime360Day(1982, 1, 16, 0, 0, 0, 0, has_year_zero=True)]

# %%
validation_set = df.loc[(df.index.get_level_values("time") > cftime.Datetime360Day(1965, 6, 16, 0, 0, 0, 0, has_year_zero=True)) & (df.index.get_level_values("time") < cftime.Datetime360Day(1982, 1, 16, 0, 0, 0, 0, has_year_zero=True))]

# %% [markdown]
# # Plots

# %% [markdown]
# Spatial projection:

# %%
fig, ax = plot.subplots(axwidth=4.5, tight=True, proj='eck3', proj_kw={"lon_0": 180},)

ax.format(land=False, coast=True, innerborders=True, borders=True, labels=True, geogridlinewidth=0,)

map1 = ax.contourf(ds["lon"], ds["lat"], ds["pr"][0,0,:,:], cmap="IceFire", extend="both")

ax.colorbar(map1, loc="b", shrink=0.5, extendrect=True)

plt.show()
# Out:
# Figure(nrows=1, ncols=1, refwidth=4.5)

# %% [markdown]
# For a single point in space:

# %%
prec_one_point = df.loc[(df.index.get_level_values("lat") == -89.375) & (df.index.get_level_values("lon") == 0.9375)]

# %%
prec_one_point = prec_one_point[:1980] # Use just one band

prec_one_point
# Out:
#                                                    lat_bnds  lon_bnds  \
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00     -90.0       0.0
#                               1850-02-16 00:00:00     -90.0       0.0
#                               1850-03-16 00:00:00     -90.0       0.0
#                               1850-04-16 00:00:00     -90.0       0.0
#                               1850-05-16 00:00:00     -90.0       0.0
# ...                                                     ...       ...
#                               2014-08-16 00:00:00     -90.0       0.0
#                               2014-09-16 00:00:00     -90.0       0.0
#                               2014-10-16 00:00:00     -90.0       0.0
#                               2014-11-16 00:00:00     -90.0       0.0
#                               2014-12-16 00:00:00     -90.0       0.0
#
#                                                              pr  \
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00  2.528526e-06
#                               1850-02-16 00:00:00  1.196780e-06
#                               1850-03-16 00:00:00  3.137424e-07
#                               1850-04-16 00:00:00  1.142245e-06
#                               1850-05-16 00:00:00  1.526145e-06
# ...                                                         ...
#                               2014-08-16 00:00:00  1.995737e-06
#                               2014-09-16 00:00:00  2.168923e-06
#                               2014-10-16 00:00:00  2.798138e-06
#                               2014-11-16 00:00:00  3.432269e-06
#                               2014-12-16 00:00:00  1.107220e-06
#
#                                                              time_bnds
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00  1850-01-01 00:00:00
#                               1850-02-16 00:00:00  1850-02-01 00:00:00
#                               1850-03-16 00:00:00  1850-03-01 00:00:00
#                               1850-04-16 00:00:00  1850-04-01 00:00:00
#                               1850-05-16 00:00:00  1850-05-01 00:00:00
# ...                                                                ...
#                               2014-08-16 00:00:00  2014-08-01 00:00:00
#                               2014-09-16 00:00:00  2014-09-01 00:00:00
#                               2014-10-16 00:00:00  2014-10-01 00:00:00
#                               2014-11-16 00:00:00  2014-11-01 00:00:00
#                               2014-12-16 00:00:00  2014-12-01 00:00:00
#
# [1980 rows x 4 columns]

# %%
prec_one_point.columns
# Out:
# Index(['lat_bnds', 'lon_bnds', 'pr', 'time_bnds'], dtype='object')

# %%
prec_one_point = prec_one_point.set_index("time_bnds")

# %%
prec_one_point.plot(x="time_bnds", y="pr", kind="scatter", figsize=(20, 8))
# Out:
# <AxesSubplot:xlabel='time_bnds', ylabel='pr'>

# %%
prec_one_point["time_bnds"] = [cftime.date2num(ind, "days since 1850-01-01") for ind in prec_one_point["time_bnds"]]

# %%
prec_one_point
# Out:
#                                                    lat_bnds  lon_bnds  \
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00     -90.0       0.0
#                               1850-02-16 00:00:00     -90.0       0.0
#                               1850-03-16 00:00:00     -90.0       0.0
#                               1850-04-16 00:00:00     -90.0       0.0
#                               1850-05-16 00:00:00     -90.0       0.0
# ...                                                     ...       ...
#                               2014-08-16 00:00:00     -90.0       0.0
#                               2014-09-16 00:00:00     -90.0       0.0
#                               2014-10-16 00:00:00     -90.0       0.0
#                               2014-11-16 00:00:00     -90.0       0.0
#                               2014-12-16 00:00:00     -90.0       0.0
#
#                                                              pr  time_bnds
# lat     bnds lon    member_id time
# -89.375 0    0.9375 r1i1p1f2  1850-01-16 00:00:00  2.528526e-06          0
#                               1850-02-16 00:00:00  1.196780e-06         30
#                               1850-03-16 00:00:00  3.137424e-07         60
#                               1850-04-16 00:00:00  1.142245e-06         90
#                               1850-05-16 00:00:00  1.526145e-06        120
# ...                                                         ...        ...
#                               2014-08-16 00:00:00  1.995737e-06      59250
#                               2014-09-16 00:00:00  2.168923e-06      59280
#                               2014-10-16 00:00:00  2.798138e-06      59310
#                               2014-11-16 00:00:00  3.432269e-06      59340
#                               2014-12-16 00:00:00  1.107220e-06      59370
#
# [1980 rows x 4 columns]
